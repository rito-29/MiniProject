# %%
# %pip install ultralytics --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SqxHxUmH1bESmMpTc8Wo")
project = rf.workspace("field-planttutorial").project("field-plant")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo detect train data=/home/ritabratopani/Documents/MiniProj ect/yolov5/FieldPlant-11/data.yaml model=yolo11s.pt epochs=10 imgsz=640
# Out:
# Ultralytics 8.3.92 🚀 Python-3.12.3 torch-2.6.0+cu124 CPU (11th Gen Intel Core(TM) i7-1165G7 2.80GHz)
# ...

# %%
# first, display our ground truth data
from IPython.display import Image, clear_output  # to display images
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/home/ritabratopani/Documents/MiniProject/runs/detect/train2/confusion_matrix.png', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason...
# plot results.txt as results.png
Image(filename='/home/ritabratopani/Documents/MiniProject/runs/detect/train2/results.png', width=1000)  # view results.png

# %%
print("Prediction Image:")
Image(filename='/content/runs/detect/train/val_batch0_pred.jpg', width=900)
# Out:
# Validation Image:

# %%
print("Label Image:")
Image(filename='/content/runs/detect/train/val_batch2_labels.jpg', width=900)
# Out:
# Label Image:

# %%
print("P-R Curve:")
Image(filename='/content/runs/detect/train/PR_curve.png', width=900)
# Out:
# P-R Curve:

# %%
print("F1 Curve:")
Image(filename='/content/runs/detect/train/F1_curve.png', width=900)
# Out:
# F1 Curve:
